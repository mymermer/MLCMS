# %%
from utils import *

# %%
# Node - stable
A_node = np.array([[-1, 0], [0, -2]])
plot_phase_portrait(A_node, 'Node Phase Portrait')

# Focus - stable
alpha_focus = 1
A_focus = np.array([[-alpha_focus, alpha_focus], [-1, -alpha_focus]])
plot_phase_portrait(A_focus, 'Focus Phase Portrait')

# Saddle
alpha_saddle = -1
A_saddle = np.array([[-alpha_saddle, 0], [0, alpha_saddle]])
plot_phase_portrait(A_saddle, 'Saddle Phase Portrait')

# Node - unstable
A_node_unstable = np.array([[1, 0], [0, 2]])
plot_phase_portrait(A_node_unstable, 'Node Phase Portrait')

# Focus - unstable
alpha_focus = 1
A_focus_unstable = np.array([[alpha_focus, -alpha_focus], [1, alpha_focus]])
plot_phase_portrait(A_focus_unstable, 'Focus Phase Portrait')
