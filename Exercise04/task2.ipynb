# %%
from task2Utils import * #importing all the functions from task2Utils.py

# %%
def equation6(alpha: float):
    return [-1, 0, alpha]

plot_bifurcation_diagram(equation6, -1, 1, 1001, "x' = α - x² Bifurcation Diagram")

# %%
def equation7(alpha: float):
    return [-2, 0, (alpha - 3)]

plot_bifurcation_diagram(equation7, 0, 10, 1001, "x' = α - 2x² - 3 Bifurcation Diagram")
