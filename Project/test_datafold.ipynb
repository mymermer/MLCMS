# %%
from gensim.models import KeyedVectors
from data_fold import *

# %%
binary_file_path = './GoogleNews-vectors-negative300.bin'
word2vec_model = KeyedVectors.load_word2vec_format(binary_file_path, binary=True)

dmap_visualization(word2vec_model, 1000)

# %%
dmap_visualization_s_curve(1000)
