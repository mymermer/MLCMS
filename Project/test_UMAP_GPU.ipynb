# %%
from gensim.models import KeyedVectors
from UMAP_GPU import *

# %%
# Load the Word2Vec model
binary_file_path = './GoogleNews-vectors-negative300.bin' #download it and put it to your directory
word2vec_model = KeyedVectors.load_word2vec_format(binary_file_path, binary=True)

# Call the umap_visualization_word2vec function
umap_visualization_word2vec(word2vec_model, subset_size=100000, embedding_n_neighbors=10, pairwise_distances_sample_size=200)
# Out:
# Average distance in UMAP embeddings: 3.9373984026827937
# Average distance in Word2Vec dataset: 2.883116874114041
# Trustworthiness of the embedding: 0.6630501071685735

# %%
umap_visualization_swiss(n_samples=100000, embedding_n_neighbors=1000, pairwise_distances_sample_size=200)
# Out:
# Average distance in UMAP embeddings: 12.066434860229492
# Average distance in Swiss Roll dataset: 15.048304741120894
# Trustworthiness of the embedding: 0.7857450391631331
