# %%
from gensim.models import KeyedVectors
from spectral import *

# %%
# Load the Word2Vec model
binary_file_path = './GoogleNews-vectors-negative300.bin' #download it and put it to your directory
word2vec_model = KeyedVectors.load_word2vec_format(binary_file_path, binary=True)

# Call the spectral_embedding_visualization function
spectral_embedding_visualization(word2vec_model, subset_size=1000, n_components=2, eigen_solver="amg")

# %%
spectral_embedding_visualization_swiss(n_samples=5000, n_components=2, eigen_solver='amg')
