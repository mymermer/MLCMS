# %%
import numpy as np 
import matplotlib.pyplot as plt
import pandas as pd
import tensorflow as tf
import task4 as f
# Out:
# WARNING:tensorflow:From c:\Users\myusu\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
# Load the training and testing datasets
train_data = np.load("data/FireEvac_train_set.npy")
test_data = np.load("data/FireEvac_test_set.npy")

#print("train data shape : ", train_data.shape)
#print("test data shape : ", test_data.shape)

# Extract x and y positions from the datasets
x_train, y_train = train_data[:, 0], train_data[:, 1]
x_test, y_test = test_data[:, 0], test_data[:, 1]

        #Visualization (Q1)
# Create a scatter plot for the training dataset
plt.figure(figsize=(8, 6))
plt.scatter(x_train, y_train, c='blue', label='Training Data')

# Add the testing dataset to the plot
plt.scatter(x_test, y_test, c='red', label='Testing Data')

# Set plot labels and title
plt.xlabel('X positions')
plt.ylabel('Y positions')
plt.title('Fire Evacuation  Dataset - Training and Testing Data')

# Show legend
plt.legend()

# Show the plot
plt.grid(True)
plt.show()

# %%
# Rescale the x and y values of the training dataset to [-1, 1]
train_min = np.min(train_data, axis=0)
train_max = np.max(train_data, axis=0)

train_data_scaled = -1 + (2 * (train_data - train_min) / (train_max - train_min))
test_data_scaled = -1 + (2 * (test_data - train_min) / (train_max - train_min))

# Create a scatter plot for the training dataset
plt.figure(figsize=(8, 6))
plt.scatter(train_data_scaled[:, 0], train_data_scaled[:, 1], c='blue', label='Training Data Normalized')
plt.scatter(test_data_scaled[:, 0], test_data_scaled[:, 1], c='red', label='Test Data Normalized')

# Set plot labels and title
plt.xlabel('X positions (Rescaled)')
plt.ylabel('Y positions (Rescaled)')
plt.title('Fire Evacuation Dataset - Normalized Training and Testing Data')

# Show legend
plt.legend()

# Show the plot
plt.grid(True)
plt.show()

# %%
data_shape = 2 # Shape of the input data 
latent_dim = 2 # Dimension of the latent space 
model, encoder, decoder = f.VAE(data_shape, latent_dim) # Create VAE model, encoder, and decoder
# Out:
# WARNING:tensorflow:From c:\Users\myusu\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (lambda_1), but
# are not present in its tracked objects:
#   <tf.Variable 'decoder_stddev:0' shape=(2,) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:From c:\Users\myusu\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.

# %%
# Set the batch size for training
batch_size = 64

# Train the VAE model and collect loss values at specific epochs
history = model.fit(
    train_data_scaled,          # Training data
    epochs=200,                 # Number of training epochs
    batch_size=batch_size,      # Batch size for training
    validation_data=(test_data_scaled, None),  # Validation data (test set)
    verbose=1,                  # Show training progress
)


print("Training ran for ", len(history.history['loss']) ," epochs without early stopping")
# Out:
# Epoch 1/200
# 47/47 [==============================] - 2s 10ms/step - loss: 1.3238 - val_loss: 0.6824
# Epoch 2/200
# 47/47 [==============================] - 0s 3ms/step - loss: 1.0372 - val_loss: -2.0198
# Epoch 3/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.7414 - val_loss: -2.0222
# Epoch 4/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.6871 - val_loss: -3.0507
# Epoch 5/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.6289 - val_loss: -3.5679
# Epoch 6/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.5619 - val_loss: -3.6128
# Epoch 7/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.5808 - val_loss: -3.6254
# Epoch 8/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.6041 - val_loss: -3.9210
# Epoch 9/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.5991 - val_loss: -3.8202
# Epoch 10/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.5033 - val_loss: -3.8893
# Epoch 11/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4585 - val_loss: -3.9293
# Epoch 12/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4395 - val_loss: -3.9894
# Epoch 13/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4361 - val_loss: -3.9474
# Epoch 14/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4034 - val_loss: -4.0134
# Epoch 15/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3891 - val_loss: -4.1530
# Epoch 16/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3873 - val_loss: -4.2113
# Epoch 17/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4662 - val_loss: -3.5359
# Epoch 18/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4583 - val_loss: -3.9777
# Epoch 19/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4271 - val_loss: -4.0600
# Epoch 20/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4196 - val_loss: -4.1920
# Epoch 21/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4696 - val_loss: -4.0148
# Epoch 22/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4004 - val_loss: -4.0140
# Epoch 23/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4031 - val_loss: -4.0815
# Epoch 24/200
# 47/47 [==============================] - 0s 4ms/step - loss: 0.4096 - val_loss: -4.0689
# Epoch 25/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3861 - val_loss: -4.0943
# Epoch 26/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3951 - val_loss: -3.6714
# Epoch 27/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4315 - val_loss: -4.0762
# Epoch 28/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4192 - val_loss: -4.0503
# Epoch 29/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4280 - val_loss: -3.9862
# Epoch 30/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3947 - val_loss: -4.1443
# Epoch 31/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3962 - val_loss: -4.0662
# Epoch 32/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4040 - val_loss: -4.1392
# Epoch 33/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4168 - val_loss: -3.9415
# Epoch 34/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4509 - val_loss: -3.8687
# Epoch 35/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3800 - val_loss: -4.1435
# Epoch 36/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4115 - val_loss: -4.0004
# Epoch 37/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4058 - val_loss: -4.1300
# Epoch 38/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4044 - val_loss: -4.2337
# Epoch 39/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3777 - val_loss: -4.0933
# Epoch 40/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4089 - val_loss: -4.1406
# Epoch 41/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3720 - val_loss: -4.0464
# Epoch 42/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4214 - val_loss: -4.0295
# Epoch 43/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3725 - val_loss: -4.1729
# Epoch 44/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3879 - val_loss: -4.2607
# Epoch 45/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3893 - val_loss: -3.8860
# Epoch 46/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4043 - val_loss: -3.9212
# Epoch 47/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4418 - val_loss: -4.1255
# Epoch 48/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4004 - val_loss: -4.1873
# Epoch 49/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4142 - val_loss: -3.9997
# Epoch 50/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4335 - val_loss: -4.0855
# Epoch 51/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3880 - val_loss: -3.9399
# Epoch 52/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3902 - val_loss: -4.2911
# Epoch 53/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3865 - val_loss: -4.0479
# Epoch 54/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3927 - val_loss: -4.1189
# Epoch 55/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4119 - val_loss: -4.3746
# Epoch 56/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3948 - val_loss: -4.2625
# Epoch 57/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3584 - val_loss: -4.1484
# Epoch 58/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4520 - val_loss: -4.1249
# Epoch 59/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4188 - val_loss: -4.0722
# Epoch 60/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3676 - val_loss: -4.2228
# Epoch 61/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3856 - val_loss: -4.1793
# Epoch 62/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4376 - val_loss: -4.0754
# Epoch 63/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4325 - val_loss: -4.0609
# Epoch 64/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4057 - val_loss: -3.9643
# Epoch 65/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4212 - val_loss: -4.1976
# Epoch 66/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4088 - val_loss: -4.2052
# Epoch 67/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4141 - val_loss: -4.2452
# Epoch 68/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3699 - val_loss: -4.2683
# Epoch 69/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3839 - val_loss: -4.0334
# Epoch 70/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4058 - val_loss: -4.1504
# Epoch 71/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3808 - val_loss: -4.2641
# Epoch 72/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3737 - val_loss: -4.1389
# Epoch 73/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3741 - val_loss: -4.2238
# Epoch 74/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4582 - val_loss: -4.1267
# Epoch 75/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3872 - val_loss: -4.0844
# Epoch 76/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3525 - val_loss: -4.2389
# Epoch 77/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3721 - val_loss: -4.3026
# Epoch 78/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3798 - val_loss: -4.1781
# Epoch 79/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4200 - val_loss: -3.9390
# Epoch 80/200
# 47/47 [==============================] - 0s 4ms/step - loss: 0.3523 - val_loss: -4.1436
# Epoch 81/200
# 47/47 [==============================] - 0s 4ms/step - loss: 0.4270 - val_loss: -4.1325
# Epoch 82/200
# 47/47 [==============================] - 0s 5ms/step - loss: 0.3557 - val_loss: -4.1941
# Epoch 83/200
# 47/47 [==============================] - 0s 4ms/step - loss: 0.4218 - val_loss: -3.9841
# Epoch 84/200
# 47/47 [==============================] - 0s 4ms/step - loss: 0.4325 - val_loss: -4.1961
# Epoch 85/200
# 47/47 [==============================] - 0s 5ms/step - loss: 0.4010 - val_loss: -4.0508
# Epoch 86/200
# 47/47 [==============================] - 0s 5ms/step - loss: 0.3683 - val_loss: -3.8622
# Epoch 87/200
# 47/47 [==============================] - 0s 4ms/step - loss: 0.3971 - val_loss: -4.0966
# Epoch 88/200
# 47/47 [==============================] - 0s 4ms/step - loss: 0.3878 - val_loss: -4.1554
# Epoch 89/200
# 47/47 [==============================] - 0s 4ms/step - loss: 0.4058 - val_loss: -3.9786
# Epoch 90/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3828 - val_loss: -4.2449
# Epoch 91/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4081 - val_loss: -4.2568
# Epoch 92/200
# 47/47 [==============================] - 0s 4ms/step - loss: 0.4243 - val_loss: -4.3009
# Epoch 93/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4226 - val_loss: -4.1974
# Epoch 94/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3606 - val_loss: -4.2754
# Epoch 95/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4178 - val_loss: -4.1862
# Epoch 96/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4060 - val_loss: -4.1719
# Epoch 97/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3988 - val_loss: -4.1087
# Epoch 98/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3876 - val_loss: -4.2595
# Epoch 99/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4005 - val_loss: -4.2113
# Epoch 100/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4005 - val_loss: -4.1274
# Epoch 101/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4846 - val_loss: -4.1486
# Epoch 102/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3577 - val_loss: -4.2206
# Epoch 103/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4107 - val_loss: -4.3367
# Epoch 104/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3593 - val_loss: -4.1633
# Epoch 105/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3629 - val_loss: -4.2364
# Epoch 106/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4381 - val_loss: -3.9323
# Epoch 107/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3852 - val_loss: -4.1741
# Epoch 108/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4177 - val_loss: -4.2796
# Epoch 109/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3907 - val_loss: -4.2619
# Epoch 110/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3658 - val_loss: -4.0250
# Epoch 111/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3641 - val_loss: -4.2456
# Epoch 112/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3858 - val_loss: -4.1993
# Epoch 113/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3475 - val_loss: -4.2783
# Epoch 114/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4001 - val_loss: -4.1922
# Epoch 115/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4117 - val_loss: -4.2058
# Epoch 116/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3812 - val_loss: -4.0486
# Epoch 117/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3925 - val_loss: -4.0435
# Epoch 118/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3758 - val_loss: -4.1520
# Epoch 119/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3959 - val_loss: -4.3322
# Epoch 120/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4030 - val_loss: -3.9614
# Epoch 121/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3665 - val_loss: -4.3038
# Epoch 122/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3734 - val_loss: -4.1484
# Epoch 123/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3676 - val_loss: -4.2160
# Epoch 124/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3995 - val_loss: -4.1779
# Epoch 125/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3765 - val_loss: -3.9749
# Epoch 126/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3884 - val_loss: -4.1535
# Epoch 127/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4089 - val_loss: -4.1645
# Epoch 128/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3941 - val_loss: -4.1192
# Epoch 129/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3555 - val_loss: -4.2257
# Epoch 130/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3676 - val_loss: -4.1643
# Epoch 131/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3833 - val_loss: -4.1919
# Epoch 132/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4345 - val_loss: -4.1500
# Epoch 133/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3868 - val_loss: -4.1173
# Epoch 134/200
# 47/47 [==============================] - 0s 4ms/step - loss: 0.4377 - val_loss: -4.0733
# Epoch 135/200
# 47/47 [==============================] - 0s 4ms/step - loss: 0.3749 - val_loss: -4.2556
# Epoch 136/200
# 47/47 [==============================] - 0s 4ms/step - loss: 0.3966 - val_loss: -4.2248
# Epoch 137/200
# 47/47 [==============================] - 0s 4ms/step - loss: 0.3484 - val_loss: -4.3700
# Epoch 138/200
# 47/47 [==============================] - 0s 4ms/step - loss: 0.4283 - val_loss: -4.0459
# Epoch 139/200
# 47/47 [==============================] - 0s 4ms/step - loss: 0.3628 - val_loss: -4.2447
# Epoch 140/200
# 47/47 [==============================] - 0s 4ms/step - loss: 0.3739 - val_loss: -4.1893
# Epoch 141/200
# 47/47 [==============================] - 0s 4ms/step - loss: 0.3928 - val_loss: -4.2965
# Epoch 142/200
# 47/47 [==============================] - 0s 4ms/step - loss: 0.3710 - val_loss: -4.2347
# Epoch 143/200
# 47/47 [==============================] - 0s 4ms/step - loss: 0.3777 - val_loss: -4.2001
# Epoch 144/200
# 47/47 [==============================] - 0s 4ms/step - loss: 0.3875 - val_loss: -4.3196
# Epoch 145/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3838 - val_loss: -4.3654
# Epoch 146/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3832 - val_loss: -4.2561
# Epoch 147/200
# 47/47 [==============================] - 0s 4ms/step - loss: 0.3789 - val_loss: -4.1855
# Epoch 148/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3471 - val_loss: -3.8962
# Epoch 149/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3970 - val_loss: -4.2468
# Epoch 150/200
# 47/47 [==============================] - 0s 4ms/step - loss: 0.3921 - val_loss: -4.0986
# Epoch 151/200
# 47/47 [==============================] - 0s 4ms/step - loss: 0.4354 - val_loss: -4.0816
# Epoch 152/200
# 47/47 [==============================] - 0s 4ms/step - loss: 0.4080 - val_loss: -4.1456
# Epoch 153/200
# 47/47 [==============================] - 0s 4ms/step - loss: 0.3667 - val_loss: -4.3211
# Epoch 154/200
# 47/47 [==============================] - 0s 5ms/step - loss: 0.3584 - val_loss: -4.1398
# Epoch 155/200
# 47/47 [==============================] - 0s 4ms/step - loss: 0.3746 - val_loss: -4.1527
# Epoch 156/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3588 - val_loss: -4.1320
# Epoch 157/200
# 47/47 [==============================] - 0s 4ms/step - loss: 0.3656 - val_loss: -4.1766
# Epoch 158/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4021 - val_loss: -4.2036
# Epoch 159/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3621 - val_loss: -4.1348
# Epoch 160/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3790 - val_loss: -4.1894
# Epoch 161/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3550 - val_loss: -3.9882
# Epoch 162/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3825 - val_loss: -4.1374
# Epoch 163/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3861 - val_loss: -4.1471
# Epoch 164/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3822 - val_loss: -4.0518
# Epoch 165/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3888 - val_loss: -4.2021
# Epoch 166/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3607 - val_loss: -4.1732
# Epoch 167/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3424 - val_loss: -4.1787
# Epoch 168/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3738 - val_loss: -4.1769
# Epoch 169/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3545 - val_loss: -4.2096
# Epoch 170/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3599 - val_loss: -4.1310
# Epoch 171/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3695 - val_loss: -4.2430
# Epoch 172/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3836 - val_loss: -4.2991
# Epoch 173/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3491 - val_loss: -4.2357
# Epoch 174/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4050 - val_loss: -4.2694
# Epoch 175/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3555 - val_loss: -4.1284
# Epoch 176/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3784 - val_loss: -3.7776
# Epoch 177/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4269 - val_loss: -4.2198
# Epoch 178/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3864 - val_loss: -4.1562
# Epoch 179/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3558 - val_loss: -4.3373
# Epoch 180/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3819 - val_loss: -4.3101
# Epoch 181/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3648 - val_loss: -4.0874
# Epoch 182/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3723 - val_loss: -4.2738
# Epoch 183/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3685 - val_loss: -4.2854
# Epoch 184/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3731 - val_loss: -4.4137
# Epoch 185/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3646 - val_loss: -4.2280
# Epoch 186/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4373 - val_loss: -4.0400
# Epoch 187/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4092 - val_loss: -4.2601
# Epoch 188/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4079 - val_loss: -4.2368
# Epoch 189/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3704 - val_loss: -4.3455
# Epoch 190/200
# 47/47 [==============================] - 0s 4ms/step - loss: 0.3496 - val_loss: -4.4064
# Epoch 191/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3542 - val_loss: -4.1562
# Epoch 192/200
# 47/47 [==============================] - 0s 4ms/step - loss: 0.3614 - val_loss: -4.1704
# Epoch 193/200
# 47/47 [==============================] - 0s 4ms/step - loss: 0.3409 - val_loss: -4.2079
# Epoch 194/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4076 - val_loss: -4.2798
# Epoch 195/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4263 - val_loss: -4.2602
# Epoch 196/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3895 - val_loss: -4.2455
# Epoch 197/200
# 47/47 [==============================] - 0s 4ms/step - loss: 0.3437 - val_loss: -4.2549
# Epoch 198/200
# 47/47 [==============================] - 0s 4ms/step - loss: 0.3486 - val_loss: -4.3303
# Epoch 199/200
# 47/47 [==============================] - 0s 4ms/step - loss: 0.3678 - val_loss: -4.1701
# Epoch 200/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3680 - val_loss: -4.3074
# Training ran for  200  epochs without early stopping

# %%
#Extract loss values
train_loss = history.history['loss']
val_loss = history.history['val_loss']

#Plot loss curve
epochs = range(1, len(train_loss) + 1)
plt.plot(epochs, train_loss, label='Training Loss')
plt.plot(epochs, val_loss, label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('-ELBO')
plt.title('Loss Curve')
plt.legend()
plt.show()

# %%
# Assuming x_test_normalized is your normalized test set
encoded_data = encoder.predict(test_data_scaled)
decoded_data = decoder.predict(encoded_data[2])  # Index 2 contains the sampled latent vectors

# Flatten the original and reconstructed test sets
x_test_flat = test_data_scaled.reshape(test_data_scaled.shape[0], -1)
decoded_data_flat = decoded_data.reshape(decoded_data.shape[0], -1)

# Make a scatter plot
plt.scatter(x_test_flat[:, 0], x_test_flat[:, 1], label='Original Test Set', alpha=0.5)
plt.scatter(decoded_data_flat[:, 0], decoded_data_flat[:, 1], label='Reconstructed Test Set', alpha=0.5)

plt.title('Scatter Plot of Reconstructed Test Set')
plt.legend()
plt.show()
# Out:
# 19/19 [==============================] - 0s 2ms/step
# 19/19 [==============================] - 0s 1ms/step

# %%
# Number of generated samples
num_samples = 1000

# Generate random latent vectors
random_latent_vectors = np.random.normal(size=(num_samples, latent_dim))

# Decode the latent vectors
generated_samples = decoder.predict(random_latent_vectors)

# Flatten the generated samples
generated_samples_flat = generated_samples.reshape(generated_samples.shape[0], -1)

# Make a scatter plot
plt.scatter(generated_samples_flat[:, 0], generated_samples_flat[:, 1], label='Generated Samples', alpha=0.5)
plt.title('Scatter Plot of 1000 Generated Samples')
plt.show()
# Out:
# 32/32 [==============================] - 0s 2ms/step

# %%
# Number of generated samples
num_samples = 5000

# Generate random latent vectors
random_latent_vectors = np.random.normal(size=(num_samples, latent_dim))

# Decode the latent vectors
generated_samples = decoder.predict(random_latent_vectors)

# Flatten the generated samples
generated_samples_flat = generated_samples.reshape(generated_samples.shape[0], -1)

# calculate rectangle
rectangle_top_left = (130, 70)
rectangle_bottom_right = (150, 50)

top_left_scaled = -1 + (2 * (rectangle_top_left - train_min) / (train_max - train_min))
bottom_right_scaled = -1 + (2 * (rectangle_bottom_right - train_min) / (train_max - train_min))

rectangle_width = abs(top_left_scaled[0] - bottom_right_scaled[0])
rectangle_height = top_left_scaled[1] - bottom_right_scaled[1]


# Plot the rectangle
rectangle = plt.Rectangle((top_left_scaled[0], top_left_scaled[1] - rectangle_height),
                          rectangle_width, rectangle_height,
                          edgecolor='red', linewidth=2, fill=False)

# Add the scaled rectangle to the plot
plt.gca().add_patch(rectangle)

# Make a scatter plot
plt.scatter(generated_samples_flat[:, 0], generated_samples_flat[:, 1], label='Generated Samples', alpha=0.5)
plt.title('Scatter Plot of 5000 Generated Samples')
plt.show()
# Out:
# 157/157 [==============================] - 0s 1ms/step

# %%
# Rectangle coordinates
rectangle_top_left = (130, 70)
rectangle_bottom_right = (150, 50)

# Rescale the x and y values of the rectangle to [-1, 1]
rectangle_top_left = -1 + (2 * (rectangle_top_left - train_min) / (train_max - train_min))
rectangle_bottom_right = -1 + (2 * (rectangle_bottom_right - train_min) / (train_max - train_min))

# Count pedestrians inside the rectangle
pedestrians_inside = 0

for pedestrian in generated_samples:
    x, y = pedestrian
    if rectangle_top_left[0] <= x <= rectangle_bottom_right[0] and \
       rectangle_bottom_right[1] <= y <= rectangle_top_left[1]:
        pedestrians_inside += 1

print(f"Number of pedestrians inside the rectangle: {pedestrians_inside}")
# Out:
# Number of pedestrians inside the rectangle: 77
