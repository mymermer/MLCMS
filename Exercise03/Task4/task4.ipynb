# %%
import tensorflow as tf
import tensorflow_probability as tfp
import numpy as np 
import matplotlib.pyplot as plt
import pandas as pd
import sys
sys.path.append('D:/_TUM/2/Praktikum/Exercises/MLCMS_Exercises/Exercise03')
import task3_functions as f

# %%
train = np.load('D:/_TUM/2/Praktikum/Exercises/MLCMS_Exercises/Exercise03/Task4/FireEvac_train_set.npy')
test = np.load('D:/_TUM/2/Praktikum/Exercises/MLCMS_Exercises/Exercise03/Task4/FireEvac_test_set.npy')

# %%
x_train, y_train = map(list, zip(*train))
x_test, y_test = map(list, zip(*test))

# %%
# Create scatter plot
plt.scatter(x_train, y_train)

# Add labels and title
plt.title('Train data')

# Display the plot
plt.show()

# %%
# Create scatter plot
plt.scatter(x_test, y_test)

# Add labels and title
plt.title('Test data')

# Display the plot
plt.show()
