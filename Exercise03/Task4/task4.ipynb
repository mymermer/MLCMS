# %%
import numpy as np 
import matplotlib.pyplot as plt
import pandas as pd
import tensorflow as tf
#import sys
#sys.path.append('C:/Users/anton/git_repository/Exercise03')
import task4_functions as f
# Out:
# WARNING:tensorflow:From c:\Users\myusu\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
# Load the training and testing datasets
train_data = np.load("FireEvac_train_set.npy")
test_data = np.load("FireEvac_test_set.npy")

#print("train data shape : ", train_data.shape)
#print("test data shape : ", test_data.shape)

# Extract x and y positions from the datasets
x_train, y_train = train_data[:, 0], train_data[:, 1]
x_test, y_test = test_data[:, 0], test_data[:, 1]

        #Visualization (Q1)
# Create a scatter plot for the training dataset
plt.figure(figsize=(8, 6))
plt.scatter(x_train, y_train, c='blue', label='Training Data')

# Add the testing dataset to the plot
plt.scatter(x_test, y_test, c='red', label='Testing Data')

# Set plot labels and title
plt.xlabel('X positions')
plt.ylabel('Y positions')
plt.title('Fire Evacuation  Dataset - Training and Testing Data')

# Show legend
plt.legend()

# Show the plot
plt.grid(True)
plt.show()

# %%
# Rescale the x and y values of the training dataset to [-1, 1]
train_min = np.min(train_data, axis=0)
train_max = np.max(train_data, axis=0)

train_data_scaled = -1 + (2 * (train_data - train_min) / (train_max - train_min))
test_data_scaled = -1 + (2 * (test_data - train_min) / (train_max - train_min))

# Create a scatter plot for the training dataset
plt.figure(figsize=(8, 6))
plt.scatter(train_data_scaled[:, 0], train_data_scaled[:, 1], c='blue', label='Training Data Normalized')
plt.scatter(test_data_scaled[:, 0], test_data_scaled[:, 1], c='red', label='Test Data Normalized')

# Set plot labels and title
plt.xlabel('X positions (Rescaled)')
plt.ylabel('Y positions (Rescaled)')
plt.title('Fire Evacuation Dataset - Normalized Training and Testing Data')

# Show legend
plt.legend()

# Show the plot
plt.grid(True)
plt.show()

# %%
data_shape = 2 # Shape of the input data 
latent_dim = 2 # Dimension of the latent space 
model, encoder, decoder = f.VAE(data_shape, latent_dim) # Create VAE model, encoder, and decoder
# Out:
# WARNING:tensorflow:From c:\Users\myusu\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:
# The following Variables were used a Lambda layer's call (lambda_1), but
# are not present in its tracked objects:
#   <tf.Variable 'decoder_stddev:0' shape=(2,) dtype=float32>
# It is possible that this is intended behavior, but it is more likely
# an omission. This is a strong indication that this layer should be
# formulated as a subclassed Layer rather than a Lambda layer.
# WARNING:tensorflow:From c:\Users\myusu\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.

# %%
# Set the batch size for training
batch_size = 64

# Train the VAE model and collect loss values at specific epochs
history = model.fit(
    train_data_scaled,          # Training data
    epochs=200,                 # Number of training epochs
    batch_size=batch_size,      # Batch size for training
    validation_data=(test_data_scaled, None),  # Validation data (test set)
    verbose=1,                  # Show training progress
)


print("Training ran for ", len(history.history['loss']) ," epochs without early stopping")
# Out:
# Epoch 1/200
# 47/47 [==============================] - 2s 7ms/step - loss: 1.3130 - val_loss: 0.7546
# Epoch 2/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.9531 - val_loss: -2.5970
# Epoch 3/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.6436 - val_loss: -3.5805
# Epoch 4/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.5617 - val_loss: -3.7079
# Epoch 5/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.5819 - val_loss: -3.6334
# Epoch 6/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.5407 - val_loss: -3.7647
# Epoch 7/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4956 - val_loss: -3.8850
# Epoch 8/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.5089 - val_loss: -3.9706
# Epoch 9/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4594 - val_loss: -4.0183
# Epoch 10/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4958 - val_loss: -4.1036
# Epoch 11/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4770 - val_loss: -4.1786
# Epoch 12/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4651 - val_loss: -4.1362
# Epoch 13/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4339 - val_loss: -4.0861
# Epoch 14/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4133 - val_loss: -4.1913
# Epoch 15/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3887 - val_loss: -3.9542
# Epoch 16/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4064 - val_loss: -4.0424
# Epoch 17/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4600 - val_loss: -4.3106
# Epoch 18/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3965 - val_loss: -4.1334
# Epoch 19/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4004 - val_loss: -4.0791
# Epoch 20/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4327 - val_loss: -3.9840
# Epoch 21/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4480 - val_loss: -4.2029
# Epoch 22/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3926 - val_loss: -4.0366
# Epoch 23/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4382 - val_loss: -3.9037
# Epoch 24/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4532 - val_loss: -3.9336
# Epoch 25/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4070 - val_loss: -4.1539
# Epoch 26/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3778 - val_loss: -4.1246
# Epoch 27/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3815 - val_loss: -4.3002
# Epoch 28/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3670 - val_loss: -4.2018
# Epoch 29/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4041 - val_loss: -4.2653
# Epoch 30/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3888 - val_loss: -4.0033
# Epoch 31/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4425 - val_loss: -4.1436
# Epoch 32/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4444 - val_loss: -4.1025
# Epoch 33/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3805 - val_loss: -4.3065
# Epoch 34/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4247 - val_loss: -4.2626
# Epoch 35/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3716 - val_loss: -4.2679
# Epoch 36/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4443 - val_loss: -3.8516
# Epoch 37/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4281 - val_loss: -4.1523
# Epoch 38/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4300 - val_loss: -4.1801
# Epoch 39/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3868 - val_loss: -4.1806
# Epoch 40/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3895 - val_loss: -4.1069
# Epoch 41/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4027 - val_loss: -3.6417
# Epoch 42/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3739 - val_loss: -4.2024
# Epoch 43/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4484 - val_loss: -4.2243
# Epoch 44/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4499 - val_loss: -3.9837
# Epoch 45/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4107 - val_loss: -4.2270
# Epoch 46/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3819 - val_loss: -4.0146
# Epoch 47/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3885 - val_loss: -4.2239
# Epoch 48/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4077 - val_loss: -4.0234
# Epoch 49/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4149 - val_loss: -4.1094
# Epoch 50/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3845 - val_loss: -4.0847
# Epoch 51/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4446 - val_loss: -3.9937
# Epoch 52/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4210 - val_loss: -3.9821
# Epoch 53/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4447 - val_loss: -3.8958
# Epoch 54/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4201 - val_loss: -4.2618
# Epoch 55/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4175 - val_loss: -4.3238
# Epoch 56/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3496 - val_loss: -4.1510
# Epoch 57/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3733 - val_loss: -4.2638
# Epoch 58/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3820 - val_loss: -4.1254
# Epoch 59/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4349 - val_loss: -4.3196
# Epoch 60/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4161 - val_loss: -4.2036
# Epoch 61/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4064 - val_loss: -4.1224
# Epoch 62/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4020 - val_loss: -4.2036
# Epoch 63/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4135 - val_loss: -4.1811
# Epoch 64/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3763 - val_loss: -4.0102
# Epoch 65/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3885 - val_loss: -4.0636
# Epoch 66/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4114 - val_loss: -4.2871
# Epoch 67/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3808 - val_loss: -4.0588
# Epoch 68/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3954 - val_loss: -4.1742
# Epoch 69/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4067 - val_loss: -4.1325
# Epoch 70/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4122 - val_loss: -4.1583
# Epoch 71/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4089 - val_loss: -4.1167
# Epoch 72/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3853 - val_loss: -4.1419
# Epoch 73/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3747 - val_loss: -4.2122
# Epoch 74/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3393 - val_loss: -4.0344
# Epoch 75/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4065 - val_loss: -4.2378
# Epoch 76/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3930 - val_loss: -4.2405
# Epoch 77/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4207 - val_loss: -4.1468
# Epoch 78/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3987 - val_loss: -3.7097
# Epoch 79/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4027 - val_loss: -4.2274
# Epoch 80/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4247 - val_loss: -3.8429
# Epoch 81/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4288 - val_loss: -4.1399
# Epoch 82/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3688 - val_loss: -4.1838
# Epoch 83/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3754 - val_loss: -4.1710
# Epoch 84/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3958 - val_loss: -4.0902
# Epoch 85/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3381 - val_loss: -4.2428
# Epoch 86/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3866 - val_loss: -3.9743
# Epoch 87/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3615 - val_loss: -4.1593
# Epoch 88/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3769 - val_loss: -4.1457
# Epoch 89/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3929 - val_loss: -4.2094
# Epoch 90/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4050 - val_loss: -3.9750
# Epoch 91/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4345 - val_loss: -4.2443
# Epoch 92/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4039 - val_loss: -4.1694
# Epoch 93/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4188 - val_loss: -4.2621
# Epoch 94/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4008 - val_loss: -4.2814
# Epoch 95/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3409 - val_loss: -4.2786
# Epoch 96/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3332 - val_loss: -4.2167
# Epoch 97/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3846 - val_loss: -4.1779
# Epoch 98/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4083 - val_loss: -4.1422
# Epoch 99/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4183 - val_loss: -4.2657
# Epoch 100/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3935 - val_loss: -4.2385
# Epoch 101/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4038 - val_loss: -4.1710
# Epoch 102/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3802 - val_loss: -4.2280
# Epoch 103/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3690 - val_loss: -4.1416
# Epoch 104/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3867 - val_loss: -4.2329
# Epoch 105/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4165 - val_loss: -4.1948
# Epoch 106/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3961 - val_loss: -4.1788
# Epoch 107/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3641 - val_loss: -4.1831
# Epoch 108/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3909 - val_loss: -4.2942
# Epoch 109/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3846 - val_loss: -4.1124
# Epoch 110/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3306 - val_loss: -4.1267
# Epoch 111/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3788 - val_loss: -4.2392
# Epoch 112/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4383 - val_loss: -3.9999
# Epoch 113/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4216 - val_loss: -4.1761
# Epoch 114/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3761 - val_loss: -4.2466
# Epoch 115/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3949 - val_loss: -4.1288
# Epoch 116/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3919 - val_loss: -3.9839
# Epoch 117/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4274 - val_loss: -4.1376
# Epoch 118/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3641 - val_loss: -4.1337
# Epoch 119/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3757 - val_loss: -4.2423
# Epoch 120/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3924 - val_loss: -4.2982
# Epoch 121/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4150 - val_loss: -4.0286
# Epoch 122/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4153 - val_loss: -4.3133
# Epoch 123/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4137 - val_loss: -4.2723
# Epoch 124/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4065 - val_loss: -4.2523
# Epoch 125/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3762 - val_loss: -4.0645
# Epoch 126/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4204 - val_loss: -4.1849
# Epoch 127/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4179 - val_loss: -4.2509
# Epoch 128/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3469 - val_loss: -4.1835
# Epoch 129/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3853 - val_loss: -4.2721
# Epoch 130/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4099 - val_loss: -4.2917
# Epoch 131/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3916 - val_loss: -4.2312
# Epoch 132/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3854 - val_loss: -4.1787
# Epoch 133/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3824 - val_loss: -4.0783
# Epoch 134/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3848 - val_loss: -4.2694
# Epoch 135/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3935 - val_loss: -4.2013
# Epoch 136/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3960 - val_loss: -4.1851
# Epoch 137/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3590 - val_loss: -4.0235
# Epoch 138/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4055 - val_loss: -4.2305
# Epoch 139/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3706 - val_loss: -4.1405
# Epoch 140/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4025 - val_loss: -4.0590
# Epoch 141/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3725 - val_loss: -4.2263
# Epoch 142/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3964 - val_loss: -4.1058
# Epoch 143/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3945 - val_loss: -4.1895
# Epoch 144/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3669 - val_loss: -4.1951
# Epoch 145/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4563 - val_loss: -4.1144
# Epoch 146/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3928 - val_loss: -4.2197
# Epoch 147/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3969 - val_loss: -4.1809
# Epoch 148/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3659 - val_loss: -4.1199
# Epoch 149/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3678 - val_loss: -4.1836
# Epoch 150/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4067 - val_loss: -4.1398
# Epoch 151/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3792 - val_loss: -4.1825
# Epoch 152/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3999 - val_loss: -3.9759
# Epoch 153/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3720 - val_loss: -3.9998
# Epoch 154/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3632 - val_loss: -4.0951
# Epoch 155/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3939 - val_loss: -4.1750
# Epoch 156/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3955 - val_loss: -4.1169
# Epoch 157/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3383 - val_loss: -4.1477
# Epoch 158/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3635 - val_loss: -4.3006
# Epoch 159/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3630 - val_loss: -4.1563
# Epoch 160/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4008 - val_loss: -4.2462
# Epoch 161/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4128 - val_loss: -4.1345
# Epoch 162/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3836 - val_loss: -4.2299
# Epoch 163/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4092 - val_loss: -4.3000
# Epoch 164/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3557 - val_loss: -4.2574
# Epoch 165/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3824 - val_loss: -4.3514
# Epoch 166/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3939 - val_loss: -4.2680
# Epoch 167/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3669 - val_loss: -4.2143
# Epoch 168/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3632 - val_loss: -4.0131
# Epoch 169/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3708 - val_loss: -4.1885
# Epoch 170/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3794 - val_loss: -4.1700
# Epoch 171/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3554 - val_loss: -3.9960
# Epoch 172/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4072 - val_loss: -4.2276
# Epoch 173/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4036 - val_loss: -4.2331
# Epoch 174/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3470 - val_loss: -4.2608
# Epoch 175/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3835 - val_loss: -4.2668
# Epoch 176/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3845 - val_loss: -4.2399
# Epoch 177/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3981 - val_loss: -4.1702
# Epoch 178/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4067 - val_loss: -4.2073
# Epoch 179/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3985 - val_loss: -4.3600
# Epoch 180/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3768 - val_loss: -4.1761
# Epoch 181/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3751 - val_loss: -4.2570
# Epoch 182/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4333 - val_loss: -4.0874
# Epoch 183/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3666 - val_loss: -4.3547
# Epoch 184/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3844 - val_loss: -4.2064
# Epoch 185/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3975 - val_loss: -3.8746
# Epoch 186/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3999 - val_loss: -4.2511
# Epoch 187/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3915 - val_loss: -4.1672
# Epoch 188/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4312 - val_loss: -4.1511
# Epoch 189/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3660 - val_loss: -4.3151
# Epoch 190/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3554 - val_loss: -4.0847
# Epoch 191/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3893 - val_loss: -4.2113
# Epoch 192/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3784 - val_loss: -4.0804
# Epoch 193/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3966 - val_loss: -4.1110
# Epoch 194/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3427 - val_loss: -4.2425
# Epoch 195/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.5073 - val_loss: -4.1725
# Epoch 196/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4220 - val_loss: -4.2288
# Epoch 197/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3809 - val_loss: -4.2962
# Epoch 198/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4188 - val_loss: -4.3127
# Epoch 199/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3595 - val_loss: -4.1502
# Epoch 200/200
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3865 - val_loss: -4.3602
# Training ran for  200  epochs without early stopping

# %%
#Extract loss values
train_loss = history.history['loss']
val_loss = history.history['val_loss']

#Plot loss curve
epochs = range(1, len(train_loss) + 1)
plt.plot(epochs, train_loss, label='Training Loss')
plt.plot(epochs, val_loss, label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('-ELBO')
plt.title('Loss Curve')
plt.legend()
plt.show()

# %%
# Assuming x_test_normalized is your normalized test set
encoded_data = encoder.predict(test_data_scaled)
decoded_data = decoder.predict(encoded_data[2])  # Index 2 contains the sampled latent vectors

# Flatten the original and reconstructed test sets
x_test_flat = test_data_scaled.reshape(test_data_scaled.shape[0], -1)
decoded_data_flat = decoded_data.reshape(decoded_data.shape[0], -1)

# Make a scatter plot
plt.scatter(x_test_flat[:, 0], x_test_flat[:, 1], label='Original Test Set', alpha=0.5)
plt.scatter(decoded_data_flat[:, 0], decoded_data_flat[:, 1], label='Reconstructed Test Set', alpha=0.5)

plt.title('Scatter Plot of Reconstructed Test Set')
plt.legend()
plt.show()
# Out:
# 19/19 [==============================] - 0s 1ms/step
# 19/19 [==============================] - 0s 1ms/step

# %%
# Number of generated samples
num_samples = 1000

# Generate random latent vectors
random_latent_vectors = np.random.normal(size=(num_samples, latent_dim))

# Decode the latent vectors
generated_samples = decoder.predict(random_latent_vectors)

# Flatten the generated samples
generated_samples_flat = generated_samples.reshape(generated_samples.shape[0], -1)

# Make a scatter plot
plt.scatter(generated_samples_flat[:, 0], generated_samples_flat[:, 1], label='Generated Samples', alpha=0.5)
plt.title('Scatter Plot of 1000 Generated Samples')
plt.show()
# Out:
# 32/32 [==============================] - 0s 1ms/step

# %%
# Number of generated samples
num_samples = 5000

# Generate random latent vectors
random_latent_vectors = np.random.normal(size=(num_samples, latent_dim))

# Decode the latent vectors
generated_samples = decoder.predict(random_latent_vectors)

# Flatten the generated samples
generated_samples_flat = generated_samples.reshape(generated_samples.shape[0], -1)

# calculate rectangle
rectangle_top_left = (130, 70)
rectangle_bottom_right = (150, 50)

top_left_scaled = -1 + (2 * (rectangle_top_left - train_min) / (train_max - train_min))
bottom_right_scaled = -1 + (2 * (rectangle_bottom_right - train_min) / (train_max - train_min))

rectangle_width = abs(top_left_scaled[0] - bottom_right_scaled[0])
rectangle_height = top_left_scaled[1] - bottom_right_scaled[1]


# Plot the rectangle
rectangle = plt.Rectangle((top_left_scaled[0], top_left_scaled[1] - rectangle_height),
                          rectangle_width, rectangle_height,
                          edgecolor='red', linewidth=2, fill=False)

# Add the scaled rectangle to the plot
plt.gca().add_patch(rectangle)

# Make a scatter plot
plt.scatter(generated_samples_flat[:, 0], generated_samples_flat[:, 1], label='Generated Samples', alpha=0.5)
plt.title('Scatter Plot of 5000 Generated Samples')
plt.show()
# Out:
# 157/157 [==============================] - 0s 1ms/step

# %%
# Rectangle coordinates
rectangle_top_left = (130, 70)
rectangle_bottom_right = (150, 50)

# Rescale the x and y values of the rectangle to [-1, 1]
rectangle_top_left = -1 + (2 * (rectangle_top_left - train_min) / (train_max - train_min))
rectangle_bottom_right = -1 + (2 * (rectangle_bottom_right - train_min) / (train_max - train_min))

# Count pedestrians inside the rectangle
pedestrians_inside = 0

for pedestrian in generated_samples:
    x, y = pedestrian
    if rectangle_top_left[0] <= x <= rectangle_bottom_right[0] and \
       rectangle_bottom_right[1] <= y <= rectangle_top_left[1]:
        pedestrians_inside += 1

print(f"Number of pedestrians inside the rectangle: {pedestrians_inside}")
# Out:
# Number of pedestrians inside the rectangle: 32
