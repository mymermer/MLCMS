# %%
from Diffusion_Map import *
import matplotlib.pyplot as plt
from sklearn.datasets import make_swiss_roll
from pca import pca_def
import numpy as np
import warnings
import pandas as pd
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Task 2.1

# %%
X,tk = create_dataset_subtask1(1000)
visualize_dataset(X, tk)

# %%
lambda_val,phi_val=diffusion_map(X,5)
# Plotting the eigenvalues
plot_eigenValues(tk, phi_val, lambda_val, 5)

# %% [markdown]
# ## Task 2.2

# %%
# Swiss roll with 5000 points
n = 5000
x, t = make_swiss_roll(n)

# %%
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(projection='3d')
ax.scatter(x[:, 0], x[:, 1], x[:, 2], c=t)
plt.savefig("images/ex3_task2_swissRoll5000.png")
plt.show()

# %%
L = 10
lambda_val,phi_val=diffusion_map(x,L)

# %%
figname = "images/task2_5000vals.png"
plot_phi_vals(phi_val, L, t, figname)

# %% [markdown]
# ### PCA on swiss roll dataset

# %%
#PCA with 3 Principal Components
pca_energy, variance, centered_data, U, S, Vt, transformed_data, reconstructed_data = pca_def(x,3)

# %%
print("The pca energy is {:.2f}%:".format(pca_energy*100))
print("The 3 principal components are:", Vt)
# Out:
# The pca energy is 100.00%:
# The 3 principal components are: [[ 0.55149827 -0.03591985  0.83340232]
#  [-0.82924833  0.08482606  0.55240542]
#  [-0.09053655 -0.99574811  0.01699495]]

# %%
#PCA with 2 Principal components
pca_energy, variance, centered_data, U, S, Vt, transformed_data, reconstructed_data = pca_def(x,2)

# %%
print("The pca energy is {:.2f}%".format(pca_energy*100))
print("PCA energy lost is {:.2f}%".format((1-pca_energy)*100))
# Out:
# The pca energy is 71.92%
# PCA energy lost is 28.08%

# %%
# Visualizing the reconstructed data
plt.figure(figsize=(10, 8))

plt.scatter(reconstructed_data[:, 0], reconstructed_data[:, 1], label='Reconstructed Data', c=reconstructed_data[:,0], cmap='viridis')
plt.title('Reconstructed Data')

plt.savefig("images/task2_reconstructedPCA.png")
plt.tight_layout()
plt.show()

# %% [markdown]
# #### With 1000 points

# %%
n = 1000
x, t = make_swiss_roll(n)

# %%
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(projection='3d')
ax.scatter(x[:, 0], x[:, 1], x[:, 2], c=t)
plt.show()

# %%
L = 10
lambda_val,phi_val=diffusion_map(x,L)

# %%
figname = "images/task2_1000vals.png"
plot_phi_vals(phi_val, L, t,figname)

# %% [markdown]
# # Task 2.3

# %%
data3 = pd.read_csv('data/data_DMAP_PCA_vadere.txt', sep=' ')

eigenvalues, eigenvectors = diffusion_map(data3, 7)

# %%
def plot_pedestrian_path_3d(first_eigen_number: int =1):
    fig = plt.figure(figsize=(8, 8))
   
    ax = fig.add_subplot(111, projection='3d')  # Create a 3D axis

    ax.scatter(eigenvectors[:, first_eigen_number], eigenvectors[:, first_eigen_number+1], eigenvectors[:, first_eigen_number+2], c=range(len(eigenvectors)), cmap='viridis')

    
    ax.set_title(rf"$Φ_{first_eigen_number}$, $Φ_{first_eigen_number+1}$, $Φ_{first_eigen_number+2}$ Eigenfunctions")
    ax.set_xlabel(rf"$Φ_{first_eigen_number}$")
    ax.set_ylabel(rf"$Φ_{first_eigen_number+1}$")
    ax.set_zlabel(rf"""          
                  
                  $Φ_{first_eigen_number+2}$


                    """)
    ax.grid(True),


    plt.show()

for i in range(6):
    plot_pedestrian_path_3d(i)

# %%
def plot_pedestrian_path_2d(first_eigen_number: int = 1):
    fig, ax = plt.subplots(figsize=(4, 4))

    ax.scatter(eigenvectors[:, first_eigen_number], eigenvectors[:, first_eigen_number + 1], c=range(len(eigenvectors)), cmap='viridis')

    ax.set_title(rf"$Φ_{first_eigen_number}$, $Φ_{first_eigen_number+1}$ Eigenfunctions")
    ax.set_xlabel(rf"$Φ_{first_eigen_number}$")
    ax.set_ylabel(rf"$Φ_{first_eigen_number+1}$")
    ax.grid(True)

    plt.show()

for i in range(6):
    plot_pedestrian_path_2d(i)
